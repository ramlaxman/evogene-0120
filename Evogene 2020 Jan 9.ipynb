# %%
# github.com/reuven/evogene-0120

s = 'abcd'
s[0]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'd'

# %%
s[2]
# Out:
# 'c'

# %%
s[2:]
# Out:
# 'cd'

# %%
'c' in s
# Out:
# True

# %%
s.index('c')
# Out:
# 2

# %%
mylist = ['a', 'b', 'c', 'd']

mylist[0]
# Out:
# 'a'

# %%
mylist[-1]
# Out:
# 'd'

# %%
mylist[2]
# Out:
# 'c'

# %%
mylist[2:]
# Out:
# ['c', 'd']

# %%
'c' in mylist
# Out:
# True

# %%
mylist.index('c')
# Out:
# 2

# %%
# sequence -- str, list, tuple

# %%
mylist = [10, 20, 30, 40, 50]

mylist.append(60)
mylist
# Out:
# [10, 20, 30, 40, 50, 60]
