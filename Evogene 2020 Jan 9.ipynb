# %%
# github.com/reuven/evogene-0120

s = 'abcd'
s[0]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'd'

# %%
s[2]
# Out:
# 'c'

# %%
s[2:]
# Out:
# 'cd'

# %%
'c' in s
# Out:
# True

# %%
s.index('c')
# Out:
# 2
